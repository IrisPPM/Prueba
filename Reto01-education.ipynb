# %% [markdown]
# <a href="https://colab.research.google.com/github/IrisPPM/Prueba/blob/main/Reto01-education.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Analisis/Inequality in Education.csv')

# %%
df.head()
# Out:
#   ISO3               Country Human Development Groups UNDP Developing Regions  \
# 0  AFG           Afghanistan                      Low                      SA
# 1  AGO                Angola                   Medium                     SSA
# 2  ALB               Albania                     High                     ECA
# 3  AND               Andorra                Very High                     NaN
# 4  ARE  United Arab Emirates                Very High                      AS
#
#    HDI Rank (2021)  Inequality in Education (2010)  \
# 0            180.0                       42.809000
# 1            148.0                             NaN
# 2             67.0                       11.900000
# 3             40.0                       15.160302
# 4             26.0                             NaN
#
#    Inequality in Education (2011)  Inequality in Education (2012)  \
# 0                       44.823380                       44.823380
# ...

# %%
df = df.drop(0,axis=0)

# %%
df
# Out:
#     ISO3               Country Human Development Groups  \
# 1    AGO                Angola                   Medium
# 2    ALB               Albania                     High
# 3    AND               Andorra                Very High
# 4    ARE  United Arab Emirates                Very High
# 5    ARG             Argentina                Very High
# ..   ...                   ...                      ...
# 190  WSM                 Samoa                     High
# 191  YEM                 Yemen                      Low
# 192  ZAF          South Africa                     High
# 193  ZMB                Zambia                   Medium
# 194  ZWE              Zimbabwe                   Medium
#
#     UNDP Developing Regions  HDI Rank (2021)  Inequality in Education (2010)  \
# 1                       SSA            148.0                             NaN
# 2                       ECA             67.0                       11.900000
# ...

# %%
df.describe()
# Out:
#        HDI Rank (2021)  Inequality in Education (2010)  \
# count       190.000000                      136.000000
# mean         95.368421                       20.491518
# std          55.112497                       14.318432
# min           1.000000                        1.322970
# 25%          48.250000                        6.916404
# 50%          95.500000                       17.678959
# 75%         142.250000                       30.286773
# max         191.000000                       48.723000
#
#        Inequality in Education (2011)  Inequality in Education (2012)  \
# count                      149.000000                      156.000000
# mean                        19.825168                       19.311160
# std                         14.244401                       14.205699
# min                          1.385640                        1.390450
# 25%                          6.100000                        5.977320
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 1 to 194
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ISO3                            194 non-null    object
#  1   Country                         194 non-null    object
#  2   Human Development Groups        190 non-null    object
#  3   UNDP Developing Regions         150 non-null    object
#  4   HDI Rank (2021)                 190 non-null    float64
#  5   Inequality in Education (2010)  136 non-null    float64
#  6   Inequality in Education (2011)  149 non-null    float64
#  7   Inequality in Education (2012)  156 non-null    float64
#  8   Inequality in Education (2013)  164 non-null    float64
#  9   Inequality in Education (2014)  167 non-null    float64
#  10  Inequality in Education (2015)  167 non-null    float64
#  11  Inequality in Education (2016)  167 non-null    float64
# ...

# %%
def particionar(entradas, salidas, porcentaje_entrenamiento, porcentaje_validacion, porcentaje_prueba):
    temp_size = porcentaje_validacion + porcentaje_prueba
    print(temp_size)
    x_train, x_temp, y_train, y_temp = train_test_split(entradas, salidas, test_size =temp_size)
    if(porcentaje_validacion > 0):
        test_size = porcentaje_prueba/temp_size
        x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size = test_size)
    else:
        return [x_train, None, x_temp, y_train, None, y_temp]
    return [x_train, x_val, x_test, y_train, y_val, y_test]

# %%
x = df[['sugars', 'sodium', 'fiber']]
x
# Out:
#    sugars sodium fiber
# 1       6    130    10
# 2       8     15     2
# 3       5    260     9
# 4       0    140    14
# 5       8    200     1
# ..    ...    ...   ...
# 73      3    250     0
# 74     12    140     0
# 75      3    230     3
# 76      3    200     3
# 77      8    200     1
#
# [77 rows x 3 columns]

# %%
y = df['rating']
y
# Out:
# 1     68.402973
# 2     33.983679
# 3     59.425505
# 4     93.704912
# 5     34.384843
#         ...
# 73    39.106174
# 74    27.753301
# 75    49.787445
# 76    51.592193
# 77    36.187559
# Name: rating, Length: 77, dtype: object

# %%
[x_train, x_val, x_test, y_train, y_val, y_test]  = particionar(x,y,60,10,30)
# Out:
# 40

# %%
x_train
# Out:
#    sugars sodium fiber
# 68      3    230     1
# 55      0      0     0
# 27      7      0     3
# 73      3    250     0
# 20      7    140     4
# 54      3    320     1
# 21      0     80     1
# 77      8    200     1
# 35      4     75     3
# 45    NaN    NaN   NaN
# 66      0      0     3
# 57      6    135     2
# 70      3    200     0
# 50      7    220     3
# 18     12     90     1
# 59     12    210     5
# 64      0      0     3
# 47     13    150     3
# 39      6    170     1
# 23     10    140     2
# 7      14    125     1
# 62      2    240     0
# 30     12    135     0
# 48      6    220     2
# 22      3    220     1
# 75      3    230     3
# 16      3    280     0
# 34      3    170     3
# 3       5    260     9
# 51      2    170     3
# 32      9    280     0
# 41      3    260     0
# 14      7    140     2
# 29     12    240     5
# 11     12    220     0
# 67     15     70     1
# 53     14    200     6

# %%
x_val
# Out:
#    sugars sodium fiber
# 43     12    180     0
# 28    NaN    NaN   NaN
# 60      8    140   2.5
# 38     11    180     0
# 56      0      0     1
# 15     13    180     0
# 6      10    180   1.5
# 44      3      0     0
# 24      5    190     1
# 76      3    200     3
