# %% [markdown]
# <a href="https://colab.research.google.com/github/IrisPPM/Prueba/blob/main/Reto01-dimonds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Analisis/diamonds.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df = df.drop(0,axis=0)

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 1      3.84  2.31
# 2      4.07  2.31
# 3      4.23  2.63
# 4      4.35  2.75
# 5      3.96  2.48
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [53939 rows x 11 columns]

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53939.000000  53939.000000  53939.000000  53939.000000  53939.000000
# mean   26971.000000      0.797950     61.749410     57.457229   3932.866590
# std    15570.992422      0.474009      1.432634      2.234486   3989.446491
# min        2.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13486.500000      0.400000     61.000000     56.000000    950.000000
# 50%    26971.000000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.500000      1.040000     62.500000     59.000000   5324.500000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53939.000000  53939.000000  53939.000000
# mean       5.731190      5.734558      3.538754
# std        1.121745      1.142120      0.705689
# min        0.000000      0.000000      0.000000
# 25%        4.710000      4.720000      2.910000
# 50%        5.700000      5.710000      3.530000
# 75%        6.540000      6.540000      4.040000
# max       10.740000     58.900000     31.800000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53939 entries, 1 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53939 non-null  int64
#  1   carat       53939 non-null  float64
#  2   cut         53939 non-null  object
#  3   color       53939 non-null  object
#  4   clarity     53939 non-null  object
#  5   depth       53939 non-null  float64
#  6   table       53939 non-null  float64
#  7   price       53939 non-null  int64
#  8   x           53939 non-null  float64
#  9   y           53939 non-null  float64
#  10  z           53939 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
def particionar(entradas, salidas, porcentaje_entrenamiento, porcentaje_validacion, porcentaje_prueba):
    temp_size = porcentaje_validacion + porcentaje_prueba
    print(temp_size)
    x_train, x_temp, y_train, y_temp = train_test_split(entradas, salidas, test_size =temp_size)
    if(porcentaje_validacion > 0):
        test_size = porcentaje_prueba/temp_size
        x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size = test_size)
    else:
        return [x_train, None, x_temp, y_train, None, y_temp]
    return [x_train, x_val, x_test, y_train, y_val, y_test]

# %%
x = df[['carat', 'depth']]
x
# Out:
#        carat  depth
# 1       0.21   59.8
# 2       0.23   56.9
# 3       0.29   62.4
# 4       0.31   63.3
# 5       0.24   62.8
# ...      ...    ...
# 53935   0.72   60.8
# 53936   0.72   63.1
# 53937   0.70   62.8
# 53938   0.86   61.0
# 53939   0.75   62.2
#
# [53939 rows x 2 columns]

# %%
y = df['price']
y
# Out:
# 1         326
# 2         327
# 3         334
# 4         335
# 5         336
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53939, dtype: int64

# %%
[x_train, x_val, x_test, y_train, y_val, y_test]  = particionar(x,y,60,10,30)
# Out:
# 40

# %%
x_train
# Out:
#        carat  depth
# 11411   1.00   61.5
# 51845   0.70   63.8
# 34404   0.34   61.7
# 45379   0.50   61.3
# 9853    1.07   61.5
# ...      ...    ...
# 48446   0.51   63.1
# 43469   0.39   61.5
# 25313   2.07   63.6
# 26559   2.26   56.9
# 51518   0.72   63.0
#
# [53899 rows x 2 columns]

# %%
x_val
# Out:
#        carat  depth
# 2719    0.26   63.6
# 52708   0.80   62.4
# 10166   1.03   61.8
# 50575   0.73   61.8
# 22168   1.51   62.5
# 12731   1.16   64.2
# 53229   0.81   63.8
# 21072   1.16   60.9
# 46645   0.30   62.1
# 2338    0.74   62.3
